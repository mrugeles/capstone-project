# %%
import numpy as np
import pandas as pd
from time import time
import matplotlib.pyplot as plt
from IPython.display import display 


# Pretty display for notebooks
# %matplotlib inline
pd.set_option('display.max_colwidth', -1)

dataset = pd.read_csv("datasets/dataset_encoded.csv")
dataset = dataset.drop(['Unnamed: 0'], axis = 1)
display(dataset.head(n = 5))
# Out:
#    AFEC_DPTO  AFEC_EDADR  AFEC_EDUC  AFEC_GENERO  AFEC_GETNICO  AFEC_MPIO  \
# 0  0.159108   0.233195    0.165027   0.171842     0.196613      0.158095
# 1  0.182208   0.246041    0.165027   0.198391     0.196613      0.151685
# 2  0.200419   0.233195    0.190694   0.198391     0.196613      0.196657
# 3  0.261765   0.233195    0.274073   0.198391     0.196613      0.288224
# 4  0.189494   0.233195    0.165027   0.198391     0.196613      0.196716
#
#    AFEC_PARENTESCO  AFEC_POBESPECIAL  AFEC_REGAFILIACION  AFEC_TIPOPER  \
# 0  0.234418         0.185798          0.247397            0.182693
# 1  0.234418         0.185798          0.247397            0.182693
# 2  0.276908         0.185798          0.163945            0.182693
# 3  0.268976         0.185798          0.163945            0.182693
# 4  0.268976         0.326796          0.163945            0.182693
#
#       ...       PET_DPTO  PET_MPIO  PET_TIPOPER  PQR_CANAL  PQR_CLASE_SNS  \
# 0     ...       0.115756  0.161965  0.097005     0.071460   0.215504
# 1     ...       0.136739  0.101469  0.129838     0.080834   0.215504
# 2     ...       0.170398  0.139685  0.129838     0.080834   0.215504
# 3     ...       0.210334  0.232032  0.129838     0.382929   0.215504
# 4     ...       0.141061  0.152191  0.129838     0.382929   0.215504
#
#    PQR_ESTADO  PQR_TIPOATENCION  PQR_TIPOPETICION      TRIM  RIESGO_VIDA
# 0  0.063637    0.078341          0.213982          0.123776  0
# 1  0.063637    0.153969          0.213982          0.123776  0
# 2  0.063637    0.153969          0.213982          0.123776  0
# 3  0.063637    0.153969          0.213982          0.123776  0
# 4  0.691235    0.153969          0.213982          0.123776  1
#
# [5 rows x 43 columns]
