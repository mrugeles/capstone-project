# %%
import numpy as np
import pandas as pd
import seaborn as sns
from time import time
import matplotlib.pyplot as plt
from IPython.display import display 
import data_utils as data_utils

# Pretty display for notebooks
# %matplotlib inline
pd.set_option('display.max_colwidth', -1)

dataset = pd.read_csv("datasets/dataset.csv.gz", compression='gzip')
dataset = dataset.drop(['Unnamed: 0'], axis = 1)
display(dataset.head(n = 5))
# Out:
#    AFEC_DPTO  AFEC_EDADR  AFEC_EDUC  AFEC_GENERO  AFEC_GETNICO  AFEC_MPIO  \
# 0  0.582583   0.833333    0.594595   0.526026     0.728228      0.548549
# 1  0.732733   0.859359    0.594595   1.000000     0.728228      0.465910
# 2  0.860861   0.833333    0.791792   1.000000     0.728228      0.833834
# 3  0.979980   0.833333    1.000000   1.000000     0.728228      0.980480
# 4  0.744745   0.833333    0.594595   1.000000     0.728228      0.861862
#
#    AFEC_PARENTESCO  AFEC_POBESPECIAL  AFEC_REGAFILIACION  AFEC_TIPOPER  \
# 0  0.852853         0.706206          1.000000            1.0
# 1  0.852853         0.706206          1.000000            1.0
# 2  0.916917         0.706206          0.575075            1.0
# 3  0.909910         0.706206          0.575075            1.0
# 4  0.909910         0.977978          0.575075            1.0
#
#       ...       PATOLOGIA_TIPO  PET_COD_DEPTO  PET_MPIO  PET_TIPOPER  \
# 0     ...       0.608108        0.399900       0.823824  0.031532
# 1     ...       0.608108        0.702703       0.406899  1.000000
# 2     ...       0.608108        0.622122       0.641642  1.000000
# 3     ...       0.608108        0.979479       0.974975  1.000000
# 4     ...       0.962963        0.766266       0.711211  1.000000
#
#    PQR_CANAL  PQR_CLASE_SNS  PQR_TIPOATENCION  PQR_TIPOPETICION     TRIM  \
# 0  0.040541   1.0            0.168669          0.715716          0.42993
# 1  0.596096   1.0            1.000000          0.715716          0.42993
# 2  0.596096   1.0            1.000000          0.715716          0.42993
# 3  1.000000   1.0            1.000000          0.715716          0.42993
# 4  1.000000   1.0            1.000000          0.715716          0.42993
#
#    RIESGO_VIDA
# 0  0
# 1  0
# 2  0
# 3  0
# 4  1
#
# [5 rows x 36 columns]

# %%
plt.figure(figsize=(16, 16))

ax = sns.heatmap(dataset.corr(), cmap = "RdBu_r", annot=True, fmt='.1f')
